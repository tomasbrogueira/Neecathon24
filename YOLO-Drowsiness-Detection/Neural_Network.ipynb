# %% [markdown]
# # 1. Imports

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import requests
from PIL import Image
from io import BytesIO
import uuid   # Unique identifier
import os
import time

device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # 2. Develop the Neural Network

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 50 --data dataset.yml --weights yolov5s.pt --workers 2 --device cpu
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
#
# [Epoch 1/50] Training Progress:
#
# [Epoch 2/50] Training Progress:
#
# [Epoch 3/50] Training Progress:
#
# [Epoch 4/50] Training Progress:
#
# [Epoch 5/50] Training Progress:
#
# [Epoch 6/50] Training Progress:
#
# [Epoch 7/50] Training Progress:
#
# [Epoch 8/50] Training Progress:
#
# [Epoch 9/50] Training Progress:
#
# [Epoch 10/50] Training Progress:
#
# [Epoch 11/50] Training Progress:
#
# [Epoch 12/50] Training Progress:
#
# [Epoch 13/50] Training Progress:
#
# [Epoch 14/50] Training Progress:
#
# [Epoch 15/50] Training Progress:
#
# [Epoch 16/50] Training Progress:
#
# [Epoch 17/50] Training Progress:
#
# [Epoch 18/50] Training Progress:
#
# [Epoch 19/50] Training Progress:
#
# [Epoch 20/50] Training Progress:
#
# [Epoch 21/50] Training Progress:
#
# [Epoch 22/50] Training Progress:
#
# [Epoch 23/50] Training Progress:
#
# [Epoch 24/50] Training Progress:
#
# ...

# %% [markdown]
# # 3. Create the Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp4/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\vasco/.cache\torch\hub\master.zip
# YOLOv5  2024-12-1 Python-3.11.1 torch-2.5.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %% [markdown]
# # 4. Load Custom Model

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\vasco/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\vasco/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\vasco/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\vasco/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
